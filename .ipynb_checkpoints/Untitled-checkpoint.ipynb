# %%
from langchain_openai import OpenAIEmbeddings
from langchain_pinecone import PineconeVectorStore

print("✅ All imports successful")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 2
#       1 from langchain_openai import OpenAIEmbeddings
# ----> 2 from langchain_pinecone import PineconeVectorStore
#       4 print("✅ All imports successful")
#
# File ~/Documents/personal/gauntlet/week2/.venv/lib/python3.10/site-packages/langchain_pinecone/__init__.py:1
# ----> 1 from langchain_pinecone.embeddings import PineconeEmbeddings, PineconeSparseEmbeddings
#       2 from langchain_pinecone.rerank import PineconeRerank
#       3 from langchain_pinecone.vectorstores import Pinecone, PineconeVectorStore
#
# File ~/Documents/personal/gauntlet/week2/.venv/lib/python3.10/site-packages/langchain_pinecone/embeddings.py:7
#       5 from langchain_core.utils import secret_from_env
#       6 from pinecone import Pinecone as PineconeClient  # type: ignore[import-untyped]
# ----> 7 from pinecone import (
#       8     PineconeAsyncio as PineconeAsyncioClient,  # type: ignore[import-untyped]
#       9 )
#      10 from pinecone import SparseValues
#      12 from langchain_pinecone._utilities import (
#      13     aget_pinecone_supported_models,
#      14     get_pinecone_supported_models,
#      15 )
#
# ImportError: cannot import name 'PineconeAsyncio' from 'pinecone' (/home/jaehyon/Documents/personal/gauntlet/week2/.venv/lib/python3.10/site-packages/pinecone/__init__.py)
